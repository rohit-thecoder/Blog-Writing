# %%
from __future__ import annotations

import operator
import os
import re
from datetime import date, timedelta
from pathlib import Path
from typing import TypedDict, List, Optional, Literal, Annotated

from pydantic import BaseModel, Field

from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_core.messages import SystemMessage, HumanMessage
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
# -----------------------------
# 1) Schemas
# -----------------------------
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120–550).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False


class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"
    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]


class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # keep if Tavily provides; DO NOT rely on it
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    queries: List[str] = Field(default_factory=list)


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)


class ImageSpec(BaseModel):
    placeholder: str = Field(..., description="e.g. [[IMAGE_1]]")
    filename: str = Field(..., description="Save under images/, e.g. qkv_flow.png")
    alt: str
    caption: str
    prompt: str = Field(..., description="Prompt to send to the image model.")
    size: Literal["1024x1024", "1024x1536", "1536x1024"] = "1024x1024"
    quality: Literal["low", "medium", "high"] = "medium"


class GlobalImagePlan(BaseModel):
    md_with_placeholders: str
    images: List[ImageSpec] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)

    # reducer/image
    merged_md: str
    md_with_placeholders: str
    image_specs: List[dict]

    final: str


# -----------------------------
# 2) LLM
# -----------------------------
import os
from langchain_mistralai import ChatMistralAI

llm = ChatMistralAI(
    model="codestral-2508",
    api_key=os.getenv("MISTRAL_API_KEY"),
    temperature=0
)

# %%
# -----------------------------
# 3) Router (decide upfront)
# -----------------------------
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- If user asked for "last week/this week/latest", reflect that constraint IN THE QUERIES.
"""

def router_node(state: State) -> dict:
    
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}"),
        ]
    )

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
# -----------------------------
# 4) Research (Tavily) 
# -----------------------------
import json
from typing import List
from langchain_tavily import TavilySearch

def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    # Tool ko loop ke bahar initialize karna standard practice hai, par yahan bhi thik hai
    tool = TavilySearch(max_results=max_results)
    
    # 1. Tool ko invoke karein (Yeh string/JSON output dega)
    raw_response = tool.invoke({"query": query})
    
    # 2. String ko Python list/dict me convert karein
    try:
        results = json.loads(raw_response) if isinstance(raw_response, str) else raw_response
    except Exception:
        results = []
        
    # Agar response object ke andar 'results' key me list hai (ya direct list hai)
    if isinstance(results, dict) and "results" in results:
        results_list = results["results"]
    elif isinstance(results, list):
        results_list = results
    else:
        results_list = []

    normalized: List[dict] = []
    for r in results_list:
        if isinstance(r, dict):  # Extra safety check
            normalized.append(
                {
                    "title": r.get("title") or "",
                    "url": r.get("url") or "",
                    "snippet": r.get("content") or r.get("snippet") or "",
                    "published_at": r.get("published_date") or r.get("published_at"),
                    "source": r.get("source"),
                }
            )
    return normalized


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- If a published date is explicitly present in the result payload, keep it as YYYY-MM-DD.
  If missing or unclear, set published_at=null. Do NOT guess.
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:

    # take the first 10 queries from state
    queries = (state.get("queries", []) or [])
    max_results = 6

    raw_results: List[dict] = []

    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(content=f"Raw results:\n{raw_results}"),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e

    return {"evidence": list(dedup.values())}

# %%
# -----------------------------
# 5) Orchestrator (Plan)
# -----------------------------
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book:
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}"
                )
            ),
        ]
    )

    return {"plan": plan}

# -----------------------------
# 6) Fanout
# -----------------------------
def fanout(state: State):
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
# -----------------------------
# 7) Worker (write one section)
# -----------------------------
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard:
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book:
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true:
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:
    
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [(task.id, section_md)]}

# %%
# !pip install google-genai
# !pip install huggingface_hub
import os
from io import BytesIO

from dotenv import load_dotenv
from huggingface_hub import InferenceClient

load_dotenv()
# Out:
# Requirement already satisfied: google-genai in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (2.24.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from google-genai) (4.9.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.58.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from google-genai) (2.13.5)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (50.0.1)
# Requirement already satisfied: certifi in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.5 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (2.1.1)
# Requirement already satisfied: pycparser in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai) (0.6.4)
# Requirement already satisfied: huggingface_hub in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (1.26.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from huggingface_hub) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from huggingface_hub) (3.32.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from huggingface_hub) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from huggingface_hub) (1.5.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from huggingface_hub) (4.16.0)
# Requirement already satisfied: colorama in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from click<9.0.0,>=8.4.2->huggingface_hub) (0.4.6)
# Requirement already satisfied: anyio in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.9.0)
# Requirement already satisfied: certifi in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub) (1.3.1)
# True

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages (26.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
import requests
import urllib.parse

from pathlib import Path
from typing import List
from io import BytesIO

from dotenv import load_dotenv
from huggingface_hub import InferenceClient


# ============================================================
# Load environment variables
# ============================================================

load_dotenv()


# ============================================================
# 8) ReducerWithImages (subgraph)
#    merge_content -> decide_images -> generate_and_place_images
# ============================================================


def merge_content(state: State) -> dict:

    plan = state["plan"]
    assert plan is not None

    # Sections list ko sort karke complete text body prepare karein
    ordered_sections = [
        md for _, md in sorted(
            state["sections"],
            key=lambda x: x[0]
        )
    ]

    body = "\n\n".join(ordered_sections).strip()

    merged_md = f"# {plan.blog_title}\n\n{body}\n"

    return {
        "merged_md": merged_md
    }


# ============================================================
# Decide Images
# ============================================================

DECIDE_IMAGES_SYSTEM = """You are an expert technical editor.

Decide if images/diagrams are needed for THIS blog.

Rules:

- Max 3 images total.
- Each image must materially improve understanding
  (diagram/flow/table-like visual).
- Insert placeholders exactly:
  [[IMAGE_1]], [[IMAGE_2]], [[IMAGE_3]].
- If no images needed:
  md_with_placeholders must equal input and images=[].
- Avoid decorative images.
- Prefer technical diagrams with short labels.

Return strictly GlobalImagePlan.
"""


def decide_images(state: State) -> dict:

    planner = llm.with_structured_output(
        GlobalImagePlan,
        include_raw=True
    )

    merged_md = state["merged_md"]

    plan = state["plan"]
    assert plan is not None

    result = planner.invoke(
        [
            SystemMessage(
                content=DECIDE_IMAGES_SYSTEM
            ),
            HumanMessage(
                content=(
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Topic: {state['topic']}\n\n"
                    "Insert placeholders + propose image prompts.\n\n"
                    f"{merged_md}"
                )
            ),
        ]
    )

    print("\n========== IMAGE PLANNER DEBUG ==========")
    print("Result type:", type(result))
    print("Result:", result)
    print("=========================================\n")

    # include_raw=True returns a dictionary-like result
    image_plan = result.get("parsed")

    if image_plan is None:

        print("RAW OUTPUT:")
        print(result.get("raw"))

        print("\nPARSING ERROR:")
        print(result.get("parsing_error"))

        raise RuntimeError(
            "Image planning failed: Mistral did not return "
            "a valid GlobalImagePlan."
        )

    return {
        "md_with_placeholders":
            image_plan.md_with_placeholders,

        "image_specs": [
            img.model_dump()
            for img in image_plan.images
        ],
    }
# ============================================================
# Hugging Face Image Generation
# ============================================================

def _generate_image_bytes(prompt: str) -> bytes:

    hf_token = os.getenv("HF_TOKEN")

    if not hf_token:
        raise RuntimeError(
            "HF_TOKEN not found. Check your .env file."
        )

    print("\n" + "=" * 70)
    print("[HF IMAGE DEBUG]")
    print("Model   : black-forest-labs/FLUX.1-schnell")
    print("Provider: auto")
    print("Prompt  :", prompt[:300])
    print("=" * 70)

    try:

        client = InferenceClient(
            api_key=hf_token,
            provider="auto",
            timeout=120
        )

        image = client.text_to_image(
            prompt=prompt,
            model="black-forest-labs/FLUX.1-schnell"
        )

        if image is None:
            raise RuntimeError(
                "Hugging Face returned None instead of an image."
            )

        buffer = BytesIO()

        image.save(
            buffer,
            format="PNG"
        )

        image_bytes = buffer.getvalue()

        print(
            f"[HF SUCCESS] Generated {len(image_bytes)} bytes"
        )

        return image_bytes

    except Exception as e:

        print("\n[HF ERROR TYPE]")
        print(type(e).__name__)

        print("\n[HF ERROR REPR]")
        print(repr(e))

        print("\n[HF ERROR STRING]")
        print(str(e))

        import traceback

        print("\n[HF TRACEBACK]")
        traceback.print_exc()

        raise RuntimeError(
            f"Hugging Face image generation failed: "
            f"{type(e).__name__}: {repr(e)}"
        )

# ============================================================
# Generate Images + Replace Placeholders
# ============================================================

def generate_and_place_images(state: State) -> dict:

    plan = state["plan"]
    assert plan is not None

    md = (
        state.get("md_with_placeholders")
        or state["merged_md"]
    )

    image_specs = (
        state.get("image_specs", [])
        or []
    )

    # --------------------------------------------------------
    # No images suggested by LLM
    # --------------------------------------------------------

    if not image_specs:

        filename = f"{plan.blog_title}.md"

        Path(filename).write_text(
            md,
            encoding="utf-8"
        )

        print("[IMAGE] No images required.")

        return {
            "final": md
        }

    # --------------------------------------------------------
    # Create images directory
    # --------------------------------------------------------

    images_dir = Path("images")

    images_dir.mkdir(
        exist_ok=True
    )

    # --------------------------------------------------------
    # Generate each image
    # --------------------------------------------------------

    for spec in image_specs:

        placeholder = spec["placeholder"]

        filename = spec["filename"]

        out_path = images_dir / filename

        print(
            f"\n[IMAGE] Processing: {filename}"
        )

        # ----------------------------------------------------
        # Don't regenerate existing image
        # ----------------------------------------------------

        if not out_path.exists():

            try:

                # IMPORTANT:
                # Old:
                # _gemini_generate_image_bytes()

                # New:
                # Hugging Face function
                img_bytes = _generate_image_bytes(
                    spec["prompt"]
                )

                out_path.write_bytes(
                    img_bytes
                )

                print(
                    f"[IMAGE] Saved: {out_path}"
                )

            except Exception as e:

                print(
                    f"[IMAGE ERROR] {e}"
                )

                # Fallback mechanism
                # Blog generation will continue
                prompt_block = (
                    f"> **[IMAGE GENERATION FAILED]** "
                    f"{spec.get('caption', '')}\n>\n"
                    f"> **Alt:** "
                    f"{spec.get('alt', '')}\n>\n"
                    f"> **Prompt:** "
                    f"{spec.get('prompt', '')}\n>\n"
                    f"> **Error:** "
                    f"{e}\n"
                )

                md = md.replace(
                    placeholder,
                    prompt_block
                )

                continue

        # ----------------------------------------------------
        # Markdown image
        # ----------------------------------------------------

        img_md = (
            f"![{spec['alt']}](images/{filename})\n"
            f"*{spec['caption']}*"
        )

        md = md.replace(
            placeholder,
            img_md
        )

    # --------------------------------------------------------
    # Save final blog
    # --------------------------------------------------------

    filename = f"{plan.blog_title}.md"

    Path(filename).write_text(
        md,
        encoding="utf-8"
    )

    print(
        f"\n[BLOG] Final blog saved: {filename}"
    )

    return {
        "final": md
    }

# %%
# build reducer subgraph
reducer_graph = StateGraph(State)
reducer_graph.add_node("merge_content", merge_content)
reducer_graph.add_node("decide_images", decide_images)
reducer_graph.add_node("generate_and_place_images", generate_and_place_images)
reducer_graph.add_edge(START, "merge_content")
reducer_graph.add_edge("merge_content", "decide_images")
reducer_graph.add_edge("decide_images", "generate_and_place_images")
reducer_graph.add_edge("generate_and_place_images", END)
reducer_subgraph = reducer_graph.compile()

reducer_subgraph

# %%
# -----------------------------
# 9) Build main graph
# -----------------------------
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_subgraph)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()
app

# %%
# -----------------------------
# 10) Runner
# -----------------------------
def run(topic: str, as_of: Optional[str] = None):
    if as_of is None:
        as_of = date.today().isoformat()

    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "as_of": as_of,
            "recency_days": 7,
            "sections": [],
            "merged_md": "",
            "md_with_placeholders": "",
            "image_specs": [],
            "final": "",
        }
    )

    return out

# %%
run("Self Attention in Transformer Architecture with images")
# Out:
# Retrying langchain_mistralai.chat_models.ChatMistralAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised ConnectError: [WinError 10054] An existing connection was forcibly closed by the remote host.
# Retrying langchain_mistralai.chat_models.ChatMistralAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised ConnectError: [WinError 10054] An existing connection was forcibly closed by the remote host.
# Retrying langchain_mistralai.chat_models.ChatMistralAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised ConnectError: [WinError 10054] An existing connection was forcibly closed by the remote host.
# ========== IMAGE PLANNER DEBUG ==========
# Result type: <class 'dict'>
# Result: {'raw': AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '45n0KfeHf', 'type': 'function', 'function': {'name': 'GlobalImagePlan', 'arguments': '{"md_with_placeholders": "# Self Attention in Transformer Architecture\\n\\n## Introduction to Self Attention\\n\\nSelf attention is a mechanism that allows a model to weigh the importance of different parts of the input data relative to each other. Unlike traditional attention mechanisms, which compare the input to an external context, self attention operates solely on the input data itself. This makes it particularly useful for tasks like machine translation, where the model needs to understand the relationships between words in a sentence.\\n\\nAt the core of self attention are three key components: queries, keys, and values. These components are derived from the input data and are used to compute attention scores. The queries represent the current word or token that the model is focusing on, while the keys and values represent all other words or tokens in the input. The attention scores are computed by taking the dot product of the queries and keys, and then applying a softmax function to normalize the scores. These scores are then used to compute a weighted sum of the values, which represents the output of the self attention mechanism.\\n\\nTo illustrate how self attention works, let\'s consider a simple example. Suppose we have a sentence \\"The cat sat on the mat\\" and we want to compute the self attention for the word \\"sat\\". The queries, keys, and values for this word would be derived from its corresponding word embedding. The attention scores would be computed by taking the dot product of the queries for \\"sat\\" with the keys for all other words in the sentence. The softmax function would then be applied to these scores to normalize them. Finally, the weighted sum of the values would be computed to produce the output of the self attention mechanism for the word \\"sat\\".\\n\\nHere\'s a simple Python code snippet that demonstrates how to compute the attention scores for a given set of queries, keys, and values:\\n\\n```python\\nimport numpy as np\\n\\ndef compute_attention_scores(queries, keys):\\n    # Compute the dot product of queries and keys\\n    dot_product = np.dot(queries, keys.T)\\n    \\n    # Apply the softmax function to the dot product\\n    attention_scores = np.exp(dot_product) / np.sum(np.exp(dot_product), axis=1, keepdims=True)\\n    \\n    return attention_scores\\n\\n# Example usage\\nqueries = np.array([[1, 0, 1], [0, 1, 0], [1, 1, 0]])\\nkeys = np.array([[0, 0, 1], [1, 1, 0], [0, 1, 1]])\\n\\nattention_scores = compute_attention_scores(queries, keys)\\nprint(attention_scores)\\n```\\n\\nIn this example, we first compute the dot product of the queries and keys. We then apply the softmax function to the dot product to normalize the scores. The resulting attention scores represent the importance of each word in the input sentence relative to the current word.\\n\\n## Mathematical Foundation of Self Attention\\n\\nSelf attention is a mechanism that allows the model to weigh the importance of different words in a sentence relative to each other. This is achieved through a series of mathematical operations. Let\'s break down the formula for calculating attention scores:\\n\\n```math\\nAttention(Q, K, V) = softmax\\\\left(\\\\frac{QK^T}{\\\\sqrt{d_k}}\\\\right)V\\n```\\n\\nHere, `Q`, `K`, and `V` are matrices representing the queries, keys, and values, respectively. The dimension of the keys and values is denoted by `d_k`.\\n\\nThe first step in the calculation is the dot product of the queries and keys. This is represented by `QK^T`. The dot product measures the similarity between the queries and keys. The higher the dot product, the more similar the queries and keys are.\\n\\nThe next step is to scale the dot product by the square root of the dimension of the keys, `√d_k`. This is done to prevent the dot products from growing too l ...
# =========================================
#
#
# [IMAGE] Processing: qkv_flow.png
#
# ======================================================================
# [HF IMAGE DEBUG]
# Model   : black-forest-labs/FLUX.1-schnell
# Provider: auto
# Prompt  : Create a diagram showing the flow of queries, keys, and values in self attention. Include the dot product operation, softmax function, and weighted sum of values. Use clear labels and arrows to indicate the flow of data.
# ======================================================================
#
# [HF ERROR TYPE]
# HfHubHTTPError
#
# [HF ERROR REPR]
# HfHubHTTPError('(Request ID: Root=1-6aaf999e-2091053918986cfc1929fd6c;7fefd775-2ab0-4cf5-885e-9d8c874d2069)\n\n403 Forbidden: This authentication method does not have sufficient permissions to call Inference Providers on behalf of user Roha24t728.\nCannot access content at: https://router.huggingface.co/nscale/v1/images/generations.\nMake sure your token has the correct permissions.')
#
# [HF ERROR STRING]
# (Request ID: Root=1-6aaf999e-2091053918986cfc1929fd6c;7fefd775-2ab0-4cf5-885e-9d8c874d2069)
#
# 403 Forbidden: This authentication method does not have sufficient permissions to call Inference Providers on behalf of user Roha24t728.
# Cannot access content at: https://router.huggingface.co/nscale/v1/images/generations.
# Make sure your token has the correct permissions.
#
# [HF TRACEBACK]
# [IMAGE ERROR] Hugging Face image generation failed: HfHubHTTPError: HfHubHTTPError('(Request ID: Root=1-6aaf999e-2091053918986cfc1929fd6c;7fefd775-2ab0-4cf5-885e-9d8c874d2069)\n\n403 Forbidden: This authentication method does not have sufficient permissions to call Inference Providers on behalf of user Roha24t728.\nCannot access content at: https://router.huggingface.co/nscale/v1/images/generations.\nMake sure your token has the correct permissions.')
#
# [IMAGE] Processing: multi_head_attention.png
#
# ======================================================================
# [HF IMAGE DEBUG]
# Model   : black-forest-labs/FLUX.1-schnell
# Provider: auto
# Prompt  : Create a diagram showing the multi-head attention mechanism. Include multiple attention heads, each with its own queries, keys, and values. Show the concatenation and linear transformation of the outputs from each head. Use clear labels and arrows to indicate the flow of data.
# ======================================================================
# Traceback (most recent call last):
#   File "c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages\huggingface_hub\utils\_http.py", line 795, in hf_raise_for_status
#     response.raise_for_status()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages\httpx\_models.py", line 829, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '403 Forbidden' for url 'https://router.huggingface.co/nscale/v1/images/generations'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\rkroh\AppData\Local\Temp\ipykernel_2912\2226784038.py", line 159, in _generate_image_bytes
#     image = client.text_to_image(
#         prompt=prompt,
#         model="black-forest-labs/FLUX.1-schnell"
#     )
#   File "c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages\huggingface_hub\inference\_client.py", line 2575, in text_to_image
#     response = self._inner_post(request_parameters)
#   File "c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages\huggingface_hub\inference\_client.py", line 283, in _inner_post
#     hf_raise_for_status(response)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages\huggingface_hub\utils\_http.py", line 896, in hf_raise_for_status
#     raise _format(HfHubHTTPError, message, response) from e
# huggingface_hub.errors.HfHubHTTPError: (Request ID: Root=1-6aaf999e-2091053918986cfc1929fd6c;7fefd775-2ab0-4cf5-885e-9d8c874d2069)
#
# 403 Forbidden: This authentication method does not have sufficient permissions to call Inference Providers on behalf of user Roha24t728.
# Cannot access content at: https://router.huggingface.co/nscale/v1/images/generations.
# Make sure your token has the correct permissions.
# [HF ERROR TYPE]
# HfHubHTTPError
#
# [HF ERROR REPR]
# HfHubHTTPError('(Request ID: Root=1-6aaf999e-2b3f7c3371a60031257d2315;a8fda8de-5509-4e34-b74f-17b6de81d93b)\n\n403 Forbidden: This authentication method does not have sufficient permissions to call Inference Providers on behalf of user Roha24t728.\nCannot access content at: https://router.huggingface.co/nscale/v1/images/generations.\nMake sure your token has the correct permissions.')
#
# [HF ERROR STRING]
# (Request ID: Root=1-6aaf999e-2b3f7c3371a60031257d2315;a8fda8de-5509-4e34-b74f-17b6de81d93b)
#
# 403 Forbidden: This authentication method does not have sufficient permissions to call Inference Providers on behalf of user Roha24t728.
# Cannot access content at: https://router.huggingface.co/nscale/v1/images/generations.
# Make sure your token has the correct permissions.
#
# [HF TRACEBACK]
# [IMAGE ERROR] Hugging Face image generation failed: HfHubHTTPError: HfHubHTTPError('(Request ID: Root=1-6aaf999e-2b3f7c3371a60031257d2315;a8fda8de-5509-4e34-b74f-17b6de81d93b)\n\n403 Forbidden: This authentication method does not have sufficient permissions to call Inference Providers on behalf of user Roha24t728.\nCannot access content at: https://router.huggingface.co/nscale/v1/images/generations.\nMake sure your token has the correct permissions.')
#
# [IMAGE] Processing: attention_scores.png
#
# ======================================================================
# [HF IMAGE DEBUG]
# Model   : black-forest-labs/FLUX.1-schnell
# Provider: auto
# Prompt  : Create a diagram showing the calculation of attention scores using the dot product of queries and keys, followed by the application of the softmax function. Include the scaling by the square root of the dimension of the keys. Use clear labels and arrows to indicate the flow of data.
# ======================================================================
# Traceback (most recent call last):
#   File "c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages\huggingface_hub\utils\_http.py", line 795, in hf_raise_for_status
#     response.raise_for_status()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages\httpx\_models.py", line 829, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '403 Forbidden' for url 'https://router.huggingface.co/nscale/v1/images/generations'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\rkroh\AppData\Local\Temp\ipykernel_2912\2226784038.py", line 159, in _generate_image_bytes
#     image = client.text_to_image(
#         prompt=prompt,
#         model="black-forest-labs/FLUX.1-schnell"
#     )
#   File "c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages\huggingface_hub\inference\_client.py", line 2575, in text_to_image
#     response = self._inner_post(request_parameters)
#   File "c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages\huggingface_hub\inference\_client.py", line 283, in _inner_post
#     hf_raise_for_status(response)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages\huggingface_hub\utils\_http.py", line 896, in hf_raise_for_status
#     raise _format(HfHubHTTPError, message, response) from e
# huggingface_hub.errors.HfHubHTTPError: (Request ID: Root=1-6aaf999e-2b3f7c3371a60031257d2315;a8fda8de-5509-4e34-b74f-17b6de81d93b)
#
# 403 Forbidden: This authentication method does not have sufficient permissions to call Inference Providers on behalf of user Roha24t728.
# Cannot access content at: https://router.huggingface.co/nscale/v1/images/generations.
# Make sure your token has the correct permissions.
# [HF ERROR TYPE]
# HfHubHTTPError
#
# [HF ERROR REPR]
# HfHubHTTPError('(Request ID: Root=1-6aaf999f-3dd324fa3cc5056a359b30ea;9c189bdd-b771-4adf-9542-177804ffbb95)\n\n403 Forbidden: This authentication method does not have sufficient permissions to call Inference Providers on behalf of user Roha24t728.\nCannot access content at: https://router.huggingface.co/nscale/v1/images/generations.\nMake sure your token has the correct permissions.')
#
# [HF ERROR STRING]
# (Request ID: Root=1-6aaf999f-3dd324fa3cc5056a359b30ea;9c189bdd-b771-4adf-9542-177804ffbb95)
#
# 403 Forbidden: This authentication method does not have sufficient permissions to call Inference Providers on behalf of user Roha24t728.
# Cannot access content at: https://router.huggingface.co/nscale/v1/images/generations.
# Make sure your token has the correct permissions.
#
# [HF TRACEBACK]
# [IMAGE ERROR] Hugging Face image generation failed: HfHubHTTPError: HfHubHTTPError('(Request ID: Root=1-6aaf999f-3dd324fa3cc5056a359b30ea;9c189bdd-b771-4adf-9542-177804ffbb95)\n\n403 Forbidden: This authentication method does not have sufficient permissions to call Inference Providers on behalf of user Roha24t728.\nCannot access content at: https://router.huggingface.co/nscale/v1/images/generations.\nMake sure your token has the correct permissions.')
#
# [BLOG] Final blog saved: Self Attention in Transformer Architecture.md
# Traceback (most recent call last):
#   File "c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages\huggingface_hub\utils\_http.py", line 795, in hf_raise_for_status
#     response.raise_for_status()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages\httpx\_models.py", line 829, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '403 Forbidden' for url 'https://router.huggingface.co/nscale/v1/images/generations'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\rkroh\AppData\Local\Temp\ipykernel_2912\2226784038.py", line 159, in _generate_image_bytes
#     image = client.text_to_image(
#         prompt=prompt,
#         model="black-forest-labs/FLUX.1-schnell"
#     )
#   File "c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages\huggingface_hub\inference\_client.py", line 2575, in text_to_image
#     response = self._inner_post(request_parameters)
#   File "c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages\huggingface_hub\inference\_client.py", line 283, in _inner_post
#     hf_raise_for_status(response)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "c:\Users\rkroh\OneDrive\Desktop\LangGraph\myenv\Lib\site-packages\huggingface_hub\utils\_http.py", line 896, in hf_raise_for_status
#     raise _format(HfHubHTTPError, message, response) from e
# huggingface_hub.errors.HfHubHTTPError: (Request ID: Root=1-6aaf999f-3dd324fa3cc5056a359b30ea;9c189bdd-b771-4adf-9542-177804ffbb95)
#
# 403 Forbidden: This authentication method does not have sufficient permissions to call Inference Providers on behalf of user Roha24t728.
# Cannot access content at: https://router.huggingface.co/nscale/v1/images/generations.
# Make sure your token has the correct permissions.
# {'topic': 'Self Attention in Transformer Architecture with images',
#  'mode': 'hybrid',
#  'needs_research': True,
#  'queries': ['self attention in transformer architecture',
#   'self attention in transformer architecture with images',
#   'self attention in transformer architecture with code examples',
#   'self attention in transformer architecture with math equations',
#   'self attention in transformer architecture with applications'],
#  'evidence': [],
#  'plan': Plan(blog_title='Self Attention in Transformer Architecture', audience='developers', tone='technical', blog_kind='explainer', constraints=[], tasks=[Task(id=1, title='Introduction to Self Attention', goal='Understand the concept of self attention and its role in transformer architecture.', bullets=['Explain what self attention is and how it differs from traditional attention mechanisms.', 'Describe the key components of self attention: queries, keys, and values.', 'Illustrate with a simple example how self attention works.'], target_words=300, tags=[], requires_research=False, requires_citations=False, requires_code=True), Task(id=2, title='Mathematical Foundation of Self Attention', goal='Grasp the mathematical operations behind self attention.', bullets=['Break down the formula for calculating attention scores.', 'Explain the role of the softmax function in attention scores.', 'Discuss the importance of the dot product in self attention.'], target_words=300, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=3, title='Implementation of Self Attention', goal='Learn how to implement self attention in code.', bullets=['Provide a minimal code sketch for self attention.', 'Explain the steps to compute queries, keys, and values.', 'Show how to apply the softmax function to the attention scores.'], target_words=400, tags=[], requires_research=False, requires_citations=False, requires_code=True), Task(id=4, title='Multi-Head Attention', goal='Understand the concept of multi-head attention and its benefits.', bullets=['Explain what multi-head attention is and why it is used.', 'Describe how multiple attention heads work together.', 'Illustrate with an example how multi-head attention improves performance.'], target_words=300, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=5, title='Edge Cases and Failure Modes', goal='Identify potential issues and edge cases in self attention.', bullets=['Discuss scenarios where self attention might fail.', 'Explain how to handle very long sequences.', 'Provide tips for debugging self attention implementations.'], target_words=300, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=6, title='Performance and Cost Considerations', goal='Evaluate the computational cost and performance of self attention.', bullets=['Analyze the time and space complexity of self attention.', 'Discuss optimizations to reduce computational cost.', 'Compare the performance of self attention with other attention mechanisms.'], target_words=300, tags=[], requires_research=False, requires_citations=False, requires_code=False), Task(id=7, title='Security and Privacy Considerations', goal='Understand the security and privacy implications of self attention.', bullets=['Discuss potential vulnerabilities in self attention.', 'Explain how to secure self attention implementations.', 'Provide guidelines for privacy-preserving self attention.'], target_words=300, tags=[], requires_research=False, requires_citations=False, requires_code=False)]),
#  'sections': [(1,
#    '## Introduction to Self Attention\n\nSelf attention is a mechanism that allows a model to weigh the importance of different parts of the input data relative to each other. Unlike traditional attention mechanisms, which compare the input to an external context, self attention operates solely on the input data itself. This makes it particularly useful for tasks like machine translation, where the model needs to understand the relationships between words in a sentence.\n\nAt the core of self attention are three key components: queries, keys, and values. These components are derived from the input data and are used to compute attention scores. The queries represent the current word or token that the model is focusing on, while the keys and values represent all other words or tokens in the input. The attention scores are computed by taking the dot product of the queries and keys, and then applying a softmax function to normalize the scores. These scores are then used to compute a weighted sum of the values, which represents the output of the self attention mechanism.\n\nTo illustrate how self attention works, let\'s consider a simple example. Suppose we have a sentence "The cat sat on the mat" and we want to compute the self attention for the word "sat". The queries, keys, and values for this word would be derived from its corresponding word embedding. The attention scores would be computed by taking the dot product of the queries for "sat" with the keys for all other words in the sentence. The softmax function would then be applied to these scores to normalize them. Finally, the weighted sum of the values would be computed to produce the output of the self attention mechanism for the word "sat".\n\nHere\'s a simple Python code snippet that demonstrates how to compute the attention scores for a given set of queries, keys, and values:\n\n```python\nimport numpy as np\n\ndef compute_attention_scores(queries, keys):\n    # Compute the dot product of queries and keys\n    dot_product = np.dot(queries, keys.T)\n\n    # Apply the softmax function to the dot product\n    attention_scores = np.exp(dot_product) / np.sum(np.exp(dot_product), axis=1, keepdims=True)\n\n    return attention_scores\n\n# Example usage\nqueries = np.array([[1, 0, 1], [0, 1, 0], [1, 1, 0]])\nkeys = np.array([[0, 0, 1], [1, 1, 0], [0, 1, 1]])\n\nattention_scores = compute_attention_scores(queries, keys)\nprint(attention_scores)\n```\n\nIn this example, we first compute the dot product of the queries and keys. We then apply the softmax function to the dot product to normalize the scores. The resulting attention scores represent the importance of each word in the input sentence relative to the current word.'),
#   (2,
#    "## Mathematical Foundation of Self Attention\n\nSelf attention is a mechanism that allows the model to weigh the importance of different words in a sentence relative to each other. This is achieved through a series of mathematical operations. Let's break down the formula for calculating attention scores:\n\n```math\nAttention(Q, K, V) = softmax\\left(\\frac{QK^T}{\\sqrt{d_k}}\\right)V\n```\n\nHere, `Q`, `K`, and `V` are matrices representing the queries, keys, and values, respectively. The dimension of the keys and values is denoted by `d_k`.\n\nThe first step in the calculation is the dot product of the queries and keys. This is represented by `QK^T`. The dot product measures the similarity between the queries and keys. The higher the dot product, the more similar the queries and keys are.\n\nThe next step is to scale the dot product by the square root of the dimension of the keys, `√d_k`. This is done to prevent the dot products from growing too large, which can cause the softmax function to produce very small gradients.\n\nThe softmax function is then applied to the scaled dot product. The softmax function converts the attention scores into probabilities, ensuring that they sum to 1. This allows the model to interpret the attention scores as weights, which can be used to weigh the importance of the values.\n\nThe final step is to multiply the resulting weights by the values, `V`. This produces the output of the self attention mechanism, which is a weighted sum of the values. The weights are determined by the attention scores, which are calculated based on the similarity between the queries and keys.\n\nThe dot product is crucial in self attention because it allows the model to measure the similarity between the queries and keys. This similarity is then used to determine the weights for the values. The softmax function ensures that the weights are probabilities, which can be interpreted as the importance of the values."),
#   (3,
#    '## Implementation of Self Attention\n\nImplementing self attention involves several key steps: computing queries, keys, and values, calculating attention scores, and applying the softmax function. Here\'s a minimal code sketch in Python using PyTorch:\n\n```python\nimport torch\nimport torch.nn as nn\nimport torch.nn.functional as F\n\nclass SelfAttention(nn.Module):\n    def __init__(self, embed_size, heads):\n        super(SelfAttention, self).__init__()\n        self.embed_size = embed_size\n        self.heads = heads\n        self.head_dim = embed_size // heads\n\n        assert (self.head_dim * heads == embed_size), "Embed size needs to be divisible by heads"\n\n        self.values = nn.Linear(self.head_dim, self.head_dim, bias=False)\n        self.keys = nn.Linear(self.head_dim, self.head_dim, bias=False)\n        self.queries = nn.Linear(self.head_dim, self.head_dim, bias=False)\n        self.fc_out = nn.Linear(heads * self.head_dim, embed_size)\n\n    def forward(self, values, keys, query, mask):\n        N = query.shape[0]\n        value_len, key_len, query_len = values.shape[1], keys.shape[1], query.shape[1]\n\n        # Split embedding into self.heads pieces\n        values = values.reshape(N, value_len, self.heads, self.head_dim)\n        keys = keys.reshape(N, key_len, self.heads, self.head_dim)\n        queries = query.reshape(N, query_len, self.heads, self.head_dim)\n\n        values = self.values(values)\n        keys = self.keys(keys)\n        queries = self.queries(queries)\n\n        # Compute attention scores\n        energy = torch.einsum("nqhd,nkhd->nhqk", [queries, keys])\n\n        # Apply mask if provided\n        if mask is not None:\n            energy = energy.masked_fill(mask == 0, float("-1e20"))\n\n        # Apply softmax to get attention scores\n        attention = torch.softmax(energy / (self.embed_size ** (1/2)), dim=3)\n\n        out = torch.einsum("nhql,nlhd->nqhd", [attention, values]).reshape(\n            N, query_len, self.heads * self.head_dim\n        )\n\n        out = self.fc_out(out)\n        return out\n```\n\n### Steps to Compute Queries, Keys, and Values\n\n1. **Initialization**: The `SelfAttention` class is initialized with the embedding size and the number of attention heads. The embedding size is divided by the number of heads to get the dimension of each head.\n\n2. **Linear Layers**: Three linear layers (`values`, `keys`, and `queries`) are defined to transform the input embeddings into the respective components.\n\n3. **Reshaping**: The input embeddings are reshaped to split the embedding into `heads` pieces, each of dimension `head_dim`.\n\n4. **Transformation**: The reshaped embeddings are passed through the linear layers to compute the values, keys, and queries.\n\n### Applying the Softmax Function to Attention Scores\n\n1. **Energy Calculation**: The attention scores are computed using the dot product of the queries and keys. This is done efficiently using the `torch.einsum` function.\n\n2. **Masking**: If a mask is provided, it is applied to the attention scores to ignore certain positions (e.g., padding tokens).\n\n3. **Softmax**: The softmax function is applied to the attention scores to get the final attention weights. The scores are scaled by the square root of the embedding size to prevent the gradients from becoming too small.\n\n4. **Output Calculation**: The attention weights are multiplied with the values to get the final output. The output is then passed through a final linear layer to combine the heads.\n\nThis implementation provides a clear and concise way to understand and implement self attention in a transformer architecture.'),
#   (4,
#    "## Multi-Head Attention\n\nMulti-head attention is a key component of the Transformer architecture, designed to capture different types of relationships in the input data. It extends the concept of self-attention by allowing the model to focus on multiple aspects of the input simultaneously. This is achieved by using multiple attention heads, each with its own set of learnable parameters.\n\nEach attention head in a multi-head attention mechanism performs a self-attention operation independently. The input is transformed into queries, keys, and values, which are then used to compute attention scores. These scores determine the importance of each input element relative to every other element. The output of each head is a weighted sum of the values, based on the attention scores.\n\nThe outputs of all the attention heads are concatenated and linearly transformed to produce the final output of the multi-head attention layer. This approach allows the model to learn diverse representations of the input data, capturing different patterns and relationships that might be missed by a single attention head.\n\nFor example, consider a sentence where multiple words are related to each other in different ways. A single attention head might struggle to capture all these relationships simultaneously. However, with multiple heads, each head can focus on a specific type of relationship, such as subject-verb agreement or noun-adjective modification. By combining the outputs of these heads, the model can achieve a more comprehensive understanding of the input sentence.\n\nIn summary, multi-head attention enhances the Transformer's ability to model complex relationships in the input data by allowing it to focus on multiple aspects of the information simultaneously. This leads to improved performance and more accurate predictions."),
#   (5,
#    '## Edge Cases and Failure Modes\n\nSelf attention, while powerful, has its limitations and can fail under certain scenarios. Understanding these edge cases and failure modes is crucial for effective implementation and debugging.\n\n### Scenarios Where Self Attention Might Fail\n\n1. **Sparse or Noisy Data**: Self attention relies on the quality of the input data. If the input data is sparse or noisy, the attention mechanism might not be able to capture meaningful relationships, leading to poor performance.\n\n2. **Extreme Class Imbalance**: In tasks with extreme class imbalance, the attention mechanism might tend to focus more on the majority class, ignoring the minority class. This can result in biased predictions.\n\n3. **Overfitting**: While self attention can capture complex patterns, it can also overfit to the training data, especially if the model is too large or the training data is limited. Regularization techniques are essential to mitigate this issue.\n\n### Handling Very Long Sequences\n\nLong sequences pose a significant challenge for self attention due to the quadratic computational complexity of the attention mechanism. Here are some strategies to handle very long sequences:\n\n1. **Sparse Attention**: Instead of computing attention for every pair of tokens, use sparse attention mechanisms that only compute attention for a subset of tokens. This can significantly reduce the computational complexity.\n\n2. **Local Attention**: Restrict the attention to local neighborhoods within the sequence. This can be particularly effective for tasks like machine translation or text generation, where local context is often sufficient.\n\n3. **Memory Compression**: Compress the memory representation of the sequence to reduce the dimensionality of the attention mechanism. Techniques like memory networks or memory-augmented neural networks can be used to achieve this.\n\n### Debugging Self Attention Implementations\n\nDebugging self attention implementations can be challenging due to the complex nature of the attention mechanism. Here are some tips to help you debug your implementation:\n\n1. **Visualize Attention Weights**: Visualizing the attention weights can provide insights into how the model is focusing on different parts of the input. This can help you identify issues like overfitting or underfitting.\n\n2. **Check Gradient Flow**: Ensure that the gradients are flowing correctly through the attention mechanism. If the gradients are vanishing or exploding, it can indicate issues with the implementation.\n\n3. **Validate with Simpler Models**: Start with simpler models and gradually increase the complexity. This can help you isolate issues and ensure that the attention mechanism is working correctly.\n\nBy understanding these edge cases and failure modes, you can better handle the challenges of self attention and implement more robust and effective transformer architectures.'),
#   (6,
#    '## Performance and Cost Considerations\n\nSelf attention, while powerful, comes with significant computational costs. Understanding these costs is crucial for deploying transformers effectively.\n\n### Time and Space Complexity\n\nThe time complexity of self attention is O(n²d), where n is the sequence length and d is the dimension of the input embeddings. This quadratic complexity arises because each token attends to every other token in the sequence. The space complexity is also O(n²d) due to the storage requirements of the attention scores matrix.\n\n### Optimizations\n\nSeveral optimizations can mitigate the computational cost of self attention:\n\n1. **Multi-head Attention**: By splitting the attention computation into multiple heads, the model can capture different aspects of the input in parallel, reducing the dimensionality of each head and thus the overall complexity.\n2. **Sparse Attention**: Instead of attending to all tokens, sparse attention mechanisms attend to a subset of tokens, reducing the complexity to O(n√n) or O(n log n).\n3. **Low-rank Approximation**: Approximating the attention scores matrix with a low-rank decomposition can significantly reduce the computational cost.\n4. **Memory-Efficient Attention**: Techniques like memory-efficient attention (MEA) and memory-compressed attention (MCA) reduce the memory footprint of the attention mechanism.\n\n### Performance Comparison\n\nSelf attention generally outperforms other attention mechanisms in terms of performance, especially for tasks requiring long-range dependencies. However, it is more computationally expensive. Other attention mechanisms, such as local attention and strided attention, are less expensive but may not capture long-range dependencies as effectively.\n\nFor example, local attention restricts the attention to a local window around each token, reducing the complexity to O(nw), where w is the window size. Strided attention, on the other hand, attends to tokens at regular intervals, reducing the complexity to O(ns), where s is the stride length.\n\nIn summary, while self attention is powerful, its computational cost can be mitigated through various optimizations. The choice of attention mechanism depends on the specific requirements of the task, balancing performance and computational cost.'),
#   (7,
#    "## Security and Privacy Considerations\n\nSelf attention mechanisms, while powerful, introduce unique security and privacy challenges. Understanding these implications is crucial for developers implementing transformer architectures.\n\n### Potential Vulnerabilities\n\nSelf attention mechanisms can be vulnerable to adversarial attacks. For instance, an attacker could manipulate the input data to create misleading attention patterns, leading to incorrect model outputs. This is particularly concerning in applications like machine translation or sentiment analysis, where the model's output directly impacts decision-making.\n\nAnother vulnerability is the exposure of sensitive information. Since self attention mechanisms process all input tokens simultaneously, they can inadvertently reveal relationships between tokens that should remain private. For example, in a medical application, the model might inadvertently learn and expose patient relationships that should be kept confidential.\n\n### Securing Self Attention Implementations\n\nTo mitigate these vulnerabilities, developers should implement robust data sanitization techniques. This includes removing or masking sensitive information before it is processed by the self attention mechanism. Additionally, differential privacy techniques can be employed to add noise to the attention scores, making it harder for an attacker to infer sensitive information.\n\nRegular security audits and updates are also essential. Keeping the transformer models and their dependencies up-to-date can help patch known vulnerabilities. Furthermore, using secure communication protocols to transmit data to and from the model can prevent interception and manipulation of sensitive information.\n\n### Guidelines for Privacy-Preserving Self Attention\n\nPrivacy-preserving self attention involves a combination of technical and ethical considerations. Developers should prioritize data minimization, ensuring that only necessary data is collected and processed. Anonymization techniques can be used to remove personally identifiable information from the data before it is processed by the self attention mechanism.\n\nFederated learning is another approach that can be used to train transformer models on decentralized data. This allows the model to learn from data without ever having access to the raw data, thus preserving privacy. Additionally, developers should be transparent about the data collection and usage practices, ensuring that users are aware of how their data is being used and protected."),
#   (1,
#    '## Introduction to Self Attention\n\nSelf attention is a mechanism that allows a model to weigh the importance of different parts of the input data relative to each other. Unlike traditional attention mechanisms, which compare the input to an external context, self attention operates solely on the input data itself. This makes it particularly useful for tasks like machine translation, where the model needs to understand the relationships between words in a sentence.\n\nAt the core of self attention are three key components: queries, keys, and values. These components are derived from the input data and are used to compute attention scores. The queries represent the current word or token that the model is focusing on, while the keys and values represent all other words or tokens in the input. The attention scores are computed by taking the dot product of the queries and keys, and then applying a softmax function to normalize the scores. These scores are then used to compute a weighted sum of the values, which represents the output of the self attention mechanism.\n\nTo illustrate how self attention works, let\'s consider a simple example. Suppose we have a sentence "The cat sat on the mat" and we want to compute the self attention for the word "sat". The queries, keys, and values for this word would be derived from its corresponding word embedding. The attention scores would be computed by taking the dot product of the queries for "sat" with the keys for all other words in the sentence. The softmax function would then be applied to these scores to normalize them. Finally, the weighted sum of the values would be computed to produce the output of the self attention mechanism for the word "sat".\n\nHere\'s a simple Python code snippet that demonstrates how to compute the attention scores for a given set of queries, keys, and values:\n\n```python\nimport numpy as np\n\ndef compute_attention_scores(queries, keys):\n    # Compute the dot product of queries and keys\n    dot_product = np.dot(queries, keys.T)\n\n    # Apply the softmax function to the dot product\n    attention_scores = np.exp(dot_product) / np.sum(np.exp(dot_product), axis=1, keepdims=True)\n\n    return attention_scores\n\n# Example usage\nqueries = np.array([[1, 0, 1], [0, 1, 0], [1, 1, 0]])\nkeys = np.array([[0, 0, 1], [1, 1, 0], [0, 1, 1]])\n\nattention_scores = compute_attention_scores(queries, keys)\nprint(attention_scores)\n```\n\nIn this example, we first compute the dot product of the queries and keys. We then apply the softmax function to the dot product to normalize the scores. The resulting attention scores represent the importance of each word in the input sentence relative to the current word.'),
#   (2,
#    "## Mathematical Foundation of Self Attention\n\nSelf attention is a mechanism that allows the model to weigh the importance of different words in a sentence relative to each other. This is achieved through a series of mathematical operations. Let's break down the formula for calculating attention scores:\n\n```math\nAttention(Q, K, V) = softmax\\left(\\frac{QK^T}{\\sqrt{d_k}}\\right)V\n```\n\nHere, `Q`, `K`, and `V` are matrices representing the queries, keys, and values, respectively. The dimension of the keys and values is denoted by `d_k`.\n\nThe first step in the calculation is the dot product of the queries and keys. This is represented by `QK^T`. The dot product measures the similarity between the queries and keys. The higher the dot product, the more similar the queries and keys are.\n\nThe next step is to scale the dot product by the square root of the dimension of the keys, `√d_k`. This is done to prevent the dot products from growing too large, which can cause the softmax function to produce very small gradients.\n\nThe softmax function is then applied to the scaled dot product. The softmax function converts the attention scores into probabilities, ensuring that they sum to 1. This allows the model to interpret the attention scores as weights, which can be used to weigh the importance of the values.\n\nThe final step is to multiply the resulting weights by the values, `V`. This produces the output of the self attention mechanism, which is a weighted sum of the values. The weights are determined by the attention scores, which are calculated based on the similarity between the queries and keys.\n\nThe dot product is crucial in self attention because it allows the model to measure the similarity between the queries and keys. This similarity is then used to determine the weights for the values. The softmax function ensures that the weights are probabilities, which can be interpreted as the importance of the values."),
#   (3,
#    '## Implementation of Self Attention\n\nImplementing self attention involves several key steps: computing queries, keys, and values, calculating attention scores, and applying the softmax function. Here\'s a minimal code sketch in Python using PyTorch:\n\n```python\nimport torch\nimport torch.nn as nn\nimport torch.nn.functional as F\n\nclass SelfAttention(nn.Module):\n    def __init__(self, embed_size, heads):\n        super(SelfAttention, self).__init__()\n        self.embed_size = embed_size\n        self.heads = heads\n        self.head_dim = embed_size // heads\n\n        assert (self.head_dim * heads == embed_size), "Embed size needs to be divisible by heads"\n\n        self.values = nn.Linear(self.head_dim, self.head_dim, bias=False)\n        self.keys = nn.Linear(self.head_dim, self.head_dim, bias=False)\n        self.queries = nn.Linear(self.head_dim, self.head_dim, bias=False)\n        self.fc_out = nn.Linear(heads * self.head_dim, embed_size)\n\n    def forward(self, values, keys, query, mask):\n        N = query.shape[0]\n        value_len, key_len, query_len = values.shape[1], keys.shape[1], query.shape[1]\n\n        # Split embedding into self.heads pieces\n        values = values.reshape(N, value_len, self.heads, self.head_dim)\n        keys = keys.reshape(N, key_len, self.heads, self.head_dim)\n        queries = query.reshape(N, query_len, self.heads, self.head_dim)\n\n        values = self.values(values)\n        keys = self.keys(keys)\n        queries = self.queries(queries)\n\n        # Compute attention scores\n        energy = torch.einsum("nqhd,nkhd->nhqk", [queries, keys])\n\n        # Apply mask if provided\n        if mask is not None:\n            energy = energy.masked_fill(mask == 0, float("-1e20"))\n\n        # Apply softmax to get attention scores\n        attention = torch.softmax(energy / (self.embed_size ** (1/2)), dim=3)\n\n        out = torch.einsum("nhql,nlhd->nqhd", [attention, values]).reshape(\n            N, query_len, self.heads * self.head_dim\n        )\n\n        out = self.fc_out(out)\n        return out\n```\n\n### Steps to Compute Queries, Keys, and Values\n\n1. **Initialization**: The `SelfAttention` class is initialized with the embedding size and the number of attention heads. The embedding size is divided by the number of heads to get the dimension of each head.\n\n2. **Linear Layers**: Three linear layers (`values`, `keys`, and `queries`) are defined to transform the input embeddings into the respective components.\n\n3. **Reshaping**: The input embeddings are reshaped to split the embedding into `heads` pieces, each of dimension `head_dim`.\n\n4. **Transformation**: The reshaped embeddings are passed through the linear layers to compute the values, keys, and queries.\n\n### Applying the Softmax Function to Attention Scores\n\n1. **Energy Calculation**: The attention scores are computed using the dot product of the queries and keys. This is done efficiently using the `torch.einsum` function.\n\n2. **Masking**: If a mask is provided, it is applied to the attention scores to ignore certain positions (e.g., padding tokens).\n\n3. **Softmax**: The softmax function is applied to the attention scores to get the final attention weights. The scores are scaled by the square root of the embedding size to prevent the gradients from becoming too small.\n\n4. **Output Calculation**: The attention weights are multiplied with the values to get the final output. The output is then passed through a final linear layer to combine the heads.\n\nThis implementation provides a clear and concise way to understand and implement self attention in a transformer architecture.'),
#   (4,
# ...
#  'merged_md': '# Self Attention in Transformer Architecture\n\n## Introduction to Self Attention\n\nSelf attention is a mechanism that allows a model to weigh the importance of different parts of the input data relative to each other. Unlike traditional attention mechanisms, which compare the input to an external context, self attention operates solely on the input data itself. This makes it particularly useful for tasks like machine translation, where the model needs to understand the relationships between words in a sentence.\n\nAt the core of self attention are three key components: queries, keys, and values. These components are derived from the input data and are used to compute attention scores. The queries represent the current word or token that the model is focusing on, while the keys and values represent all other words or tokens in the input. The attention scores are computed by taking the dot product of the queries and keys, and then applying a softmax function to normalize the scores. These scores are then used to compute a weighted sum of the values, which represents the output of the self attention mechanism.\n\nTo illustrate how self attention works, let\'s consider a simple example. Suppose we have a sentence "The cat sat on the mat" and we want to compute the self attention for the word "sat". The queries, keys, and values for this word would be derived from its corresponding word embedding. The attention scores would be computed by taking the dot product of the queries for "sat" with the keys for all other words in the sentence. The softmax function would then be applied to these scores to normalize them. Finally, the weighted sum of the values would be computed to produce the output of the self attention mechanism for the word "sat".\n\nHere\'s a simple Python code snippet that demonstrates how to compute the attention scores for a given set of queries, keys, and values:\n\n```python\nimport numpy as np\n\ndef compute_attention_scores(queries, keys):\n    # Compute the dot product of queries and keys\n    dot_product = np.dot(queries, keys.T)\n\n    # Apply the softmax function to the dot product\n    attention_scores = np.exp(dot_product) / np.sum(np.exp(dot_product), axis=1, keepdims=True)\n\n    return attention_scores\n\n# Example usage\nqueries = np.array([[1, 0, 1], [0, 1, 0], [1, 1, 0]])\nkeys = np.array([[0, 0, 1], [1, 1, 0], [0, 1, 1]])\n\nattention_scores = compute_attention_scores(queries, keys)\nprint(attention_scores)\n```\n\nIn this example, we first compute the dot product of the queries and keys. We then apply the softmax function to the dot product to normalize the scores. The resulting attention scores represent the importance of each word in the input sentence relative to the current word.\n\n## Mathematical Foundation of Self Attention\n\nSelf attention is a mechanism that allows the model to weigh the importance of different words in a sentence relative to each other. This is achieved through a series of mathematical operations. Let\'s break down the formula for calculating attention scores:\n\n```math\nAttention(Q, K, V) = softmax\\left(\\frac{QK^T}{\\sqrt{d_k}}\\right)V\n```\n\nHere, `Q`, `K`, and `V` are matrices representing the queries, keys, and values, respectively. The dimension of the keys and values is denoted by `d_k`.\n\nThe first step in the calculation is the dot product of the queries and keys. This is represented by `QK^T`. The dot product measures the similarity between the queries and keys. The higher the dot product, the more similar the queries and keys are.\n\nThe next step is to scale the dot product by the square root of the dimension of the keys, `√d_k`. This is done to prevent the dot products from growing too large, which can cause the softmax function to produce very small gradients.\n\nThe softmax function is then applied to the scaled dot product. The softmax function converts the attention scores into probabilities, ensuring that they sum to 1. This allows  ...
#  'md_with_placeholders': '# Self Attention in Transformer Architecture\n\n## Introduction to Self Attention\n\nSelf attention is a mechanism that allows a model to weigh the importance of different parts of the input data relative to each other. Unlike traditional attention mechanisms, which compare the input to an external context, self attention operates solely on the input data itself. This makes it particularly useful for tasks like machine translation, where the model needs to understand the relationships between words in a sentence.\n\nAt the core of self attention are three key components: queries, keys, and values. These components are derived from the input data and are used to compute attention scores. The queries represent the current word or token that the model is focusing on, while the keys and values represent all other words or tokens in the input. The attention scores are computed by taking the dot product of the queries and keys, and then applying a softmax function to normalize the scores. These scores are then used to compute a weighted sum of the values, which represents the output of the self attention mechanism.\n\nTo illustrate how self attention works, let\'s consider a simple example. Suppose we have a sentence "The cat sat on the mat" and we want to compute the self attention for the word "sat". The queries, keys, and values for this word would be derived from its corresponding word embedding. The attention scores would be computed by taking the dot product of the queries for "sat" with the keys for all other words in the sentence. The softmax function would then be applied to these scores to normalize them. Finally, the weighted sum of the values would be computed to produce the output of the self attention mechanism for the word "sat".\n\nHere\'s a simple Python code snippet that demonstrates how to compute the attention scores for a given set of queries, keys, and values:\n\n```python\nimport numpy as np\n\ndef compute_attention_scores(queries, keys):\n    # Compute the dot product of queries and keys\n    dot_product = np.dot(queries, keys.T)\n    \n    # Apply the softmax function to the dot product\n    attention_scores = np.exp(dot_product) / np.sum(np.exp(dot_product), axis=1, keepdims=True)\n    \n    return attention_scores\n\n# Example usage\nqueries = np.array([[1, 0, 1], [0, 1, 0], [1, 1, 0]])\nkeys = np.array([[0, 0, 1], [1, 1, 0], [0, 1, 1]])\n\nattention_scores = compute_attention_scores(queries, keys)\nprint(attention_scores)\n```\n\nIn this example, we first compute the dot product of the queries and keys. We then apply the softmax function to the dot product to normalize the scores. The resulting attention scores represent the importance of each word in the input sentence relative to the current word.\n\n## Mathematical Foundation of Self Attention\n\nSelf attention is a mechanism that allows the model to weigh the importance of different words in a sentence relative to each other. This is achieved through a series of mathematical operations. Let\'s break down the formula for calculating attention scores:\n\n```math\nAttention(Q, K, V) = softmax\\left(\\frac{QK^T}{\\sqrt{d_k}}\\right)V\n```\n\nHere, `Q`, `K`, and `V` are matrices representing the queries, keys, and values, respectively. The dimension of the keys and values is denoted by `d_k`.\n\nThe first step in the calculation is the dot product of the queries and keys. This is represented by `QK^T`. The dot product measures the similarity between the queries and keys. The higher the dot product, the more similar the queries and keys are.\n\nThe next step is to scale the dot product by the square root of the dimension of the keys, `√d_k`. This is done to prevent the dot products from growing too large, which can cause the softmax function to produce very small gradients.\n\nThe softmax function is then applied to the scaled dot product. The softmax function converts the attention scores into probabilities, ensuring that they sum ...
#  'image_specs': [{'placeholder': '[[IMAGE_1]]',
#    'filename': 'qkv_flow.png',
#    'alt': 'QKV Flow Diagram',
#    'caption': 'The flow of queries, keys, and values in self attention.',
#    'prompt': 'Create a diagram showing the flow of queries, keys, and values in self attention. Include the dot product operation, softmax function, and weighted sum of values. Use clear labels and arrows to indicate the flow of data.',
#    'size': '1024x1024',
#    'quality': 'medium'},
#   {'placeholder': '[[IMAGE_2]]',
#    'filename': 'multi_head_attention.png',
#    'alt': 'Multi-Head Attention Diagram',
#    'caption': 'Multi-head attention mechanism with multiple attention heads.',
#    'prompt': 'Create a diagram showing the multi-head attention mechanism. Include multiple attention heads, each with its own queries, keys, and values. Show the concatenation and linear transformation of the outputs from each head. Use clear labels and arrows to indicate the flow of data.',
#    'size': '1024x1024',
#    'quality': 'medium'},
#   {'placeholder': '[[IMAGE_3]]',
#    'filename': 'attention_scores.png',
#    'alt': 'Attention Scores Calculation',
#    'caption': 'Calculation of attention scores using dot product and softmax.',
#    'prompt': 'Create a diagram showing the calculation of attention scores using the dot product of queries and keys, followed by the application of the softmax function. Include the scaling by the square root of the dimension of the keys. Use clear labels and arrows to indicate the flow of data.',
#    'size': '1024x1024',
#    'quality': 'medium'}],
#  'final': '# Self Attention in Transformer Architecture\n\n## Introduction to Self Attention\n\nSelf attention is a mechanism that allows a model to weigh the importance of different parts of the input data relative to each other. Unlike traditional attention mechanisms, which compare the input to an external context, self attention operates solely on the input data itself. This makes it particularly useful for tasks like machine translation, where the model needs to understand the relationships between words in a sentence.\n\nAt the core of self attention are three key components: queries, keys, and values. These components are derived from the input data and are used to compute attention scores. The queries represent the current word or token that the model is focusing on, while the keys and values represent all other words or tokens in the input. The attention scores are computed by taking the dot product of the queries and keys, and then applying a softmax function to normalize the scores. These scores are then used to compute a weighted sum of the values, which represents the output of the self attention mechanism.\n\nTo illustrate how self attention works, let\'s consider a simple example. Suppose we have a sentence "The cat sat on the mat" and we want to compute the self attention for the word "sat". The queries, keys, and values for this word would be derived from its corresponding word embedding. The attention scores would be computed by taking the dot product of the queries for "sat" with the keys for all other words in the sentence. The softmax function would then be applied to these scores to normalize them. Finally, the weighted sum of the values would be computed to produce the output of the self attention mechanism for the word "sat".\n\nHere\'s a simple Python code snippet that demonstrates how to compute the attention scores for a given set of queries, keys, and values:\n\n```python\nimport numpy as np\n\ndef compute_attention_scores(queries, keys):\n    # Compute the dot product of queries and keys\n    dot_product = np.dot(queries, keys.T)\n    \n    # Apply the softmax function to the dot product\n    attention_scores = np.exp(dot_product) / np.sum(np.exp(dot_product), axis=1, keepdims=True)\n    \n    return attention_scores\n\n# Example usage\nqueries = np.array([[1, 0, 1], [0, 1, 0], [1, 1, 0]])\nkeys = np.array([[0, 0, 1], [1, 1, 0], [0, 1, 1]])\n\nattention_scores = compute_attention_scores(queries, keys)\nprint(attention_scores)\n```\n\nIn this example, we first compute the dot product of the queries and keys. We then apply the softmax function to the dot product to normalize the scores. The resulting attention scores represent the importance of each word in the input sentence relative to the current word.\n\n## Mathematical Foundation of Self Attention\n\nSelf attention is a mechanism that allows the model to weigh the importance of different words in a sentence relative to each other. This is achieved through a series of mathematical operations. Let\'s break down the formula for calculating attention scores:\n\n```math\nAttention(Q, K, V) = softmax\\left(\\frac{QK^T}{\\sqrt{d_k}}\\right)V\n```\n\nHere, `Q`, `K`, and `V` are matrices representing the queries, keys, and values, respectively. The dimension of the keys and values is denoted by `d_k`.\n\nThe first step in the calculation is the dot product of the queries and keys. This is represented by `QK^T`. The dot product measures the similarity between the queries and keys. The higher the dot product, the more similar the queries and keys are.\n\nThe next step is to scale the dot product by the square root of the dimension of the keys, `√d_k`. This is done to prevent the dot products from growing too large, which can cause the softmax function to produce very small gradients.\n\nThe softmax function is then applied to the scaled dot product. The softmax function converts the attention scores into probabilities, ensuring that they sum to 1. This all ...
