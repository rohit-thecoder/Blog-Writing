# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# C:\Users\rkroh\AppData\Local\Temp\ipykernel_3972\1690773881.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools.tavily_search import TavilySearchResults
# True

# %%
# !pip install -U langchain-tavily
# Out:
# Collecting langchain-tavily
#   Downloading langchain_tavily-0.2.18-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.14 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langchain-tavily) (3.14.3)
# Requirement already satisfied: langchain<2.0.0,>=1.0.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langchain-tavily) (1.3.14)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.11 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langchain-tavily) (1.5.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langchain-tavily) (2.34.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.24.5)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langchain<2.0.0,>=1.0.0->langchain-tavily) (1.2.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langchain<2.0.0,>=1.0.0->langchain-tavily) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.4.8)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (4.14.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (15.0.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.23.0)
# Requirement already satisfied: anyio in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (4.9.0)
# Requirement already satisfied: certifi in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (1.0.9)
# Requirement already satisfied: idna in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\rkroh\onedrive\desktop\langgraph\myenv\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain<2.0.0,>=1.0.0->langchain-tavily) (1.3.1)
# Downloading langchain_tavily-0.2.18-py3-none-any.whl (30 kB)
# Installing collected packages: langchain-tavily
# Successfully installed langchain-tavily-0.2.18
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 'TavilySearchResults' ki jagah ab 'TavilySearch' use karein
from langchain_tavily import TavilySearch

# Tool ko initialize karein
tool = TavilySearch(max_results=2)

print("Tool successfully initialized!")
# Out:
# Tool successfully initialized!

# %%
for r in results:
    print(r['content'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 for r in results:
# ----> 2     print(r['content'])
#
# TypeError: string indices must be integers, not 'str'
