# %%
from __future__ import annotations

import operator
import os
import re
from datetime import date, datetime, timedelta
from pathlib import Path
from typing import TypedDict, List, Optional, Literal, Annotated

from pydantic import BaseModel, Field

from langgraph.graph import StateGraph, START, END
from langgraph.types import Send
from langchain_core.messages import SystemMessage, HumanMessage
from dotenv import load_dotenv
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
# -----------------------------
# 1) Schemas
# -----------------------------
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120–550).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False


class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str

    # NEW: tells workers what genre this is (prevents drift)
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"

    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]


class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # prefer ISO "YYYY-MM-DD"
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    reason: str
    queries: List[str] = Field(default_factory=list)
    max_results_per_query: int = Field(5, description="How many results to fetch per query (3–8).")


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # NEW: recency control
    as_of: str           # ISO date, e.g. "2026-01-29"
    recency_days: int    # 7 for weekly news, 30 for hybrid, etc.

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)
    final: str

# %%
# -----------------------------
# 2) LLM
# -----------------------------
import os
from langchain_mistralai import ChatMistralAI

llm = ChatMistralAI(
    model="codestral-2508",
    api_key=os.getenv("MISTRAL_API_KEY"),
    temperature=0
)

# %%
# -----------------------------
# 3) Router (decide upfront)
# -----------------------------
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- For open_book weekly roundup, include queries that reflect the last 7 days constraint.
"""

def router_node(state: State) -> dict:
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}\nAs-of date: {state['as_of']}"),
        ]
    )

    # Set default recency window based on mode
    if decision.mode == "open_book":
        recency_days = 7
    elif decision.mode == "hybrid":
        recency_days = 45
    else:
        recency_days = 3650

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
        "recency_days": recency_days,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
# -----------------------------
# 4) Research (Tavily)
# -----------------------------
import json
from typing import List
from langchain_tavily import TavilySearch

def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    # Tool ko loop ke bahar initialize karna standard practice hai, par yahan bhi thik hai
    tool = TavilySearch(max_results=max_results)
    
    # 1. Tool ko invoke karein (Yeh string/JSON output dega)
    raw_response = tool.invoke({"query": query})
    
    # 2. String ko Python list/dict me convert karein
    try:
        results = json.loads(raw_response) if isinstance(raw_response, str) else raw_response
    except Exception:
        results = []
        
    # Agar response object ke andar 'results' key me list hai (ya direct list hai)
    if isinstance(results, dict) and "results" in results:
        results_list = results["results"]
    elif isinstance(results, list):
        results_list = results
    else:
        results_list = []

    normalized: List[dict] = []
    for r in results_list:
        if isinstance(r, dict):  # Extra safety check
            normalized.append(
                {
                    "title": r.get("title") or "",
                    "url": r.get("url") or "",
                    "snippet": r.get("content") or r.get("snippet") or "",
                    "published_at": r.get("published_date") or r.get("published_at"),
                    "source": r.get("source"),
                }
            )
    return normalized


def _iso_to_date(s: Optional[str]) -> Optional[date]:
    if not s:
        return None
    try:
        return date.fromisoformat(s[:10])
    except Exception:
        return None


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- Extract/normalize published_at as ISO (YYYY-MM-DD) if you can infer it from title/snippet.
  If you can't infer a date reliably, set published_at=null (do NOT guess).
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:
    queries = (state.get("queries", []) or [])[:10]
    max_results = 6

    raw_results: List[dict] = []
    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(
                content=(
                    f"As-of date: {state['as_of']}\n"
                    f"Recency days: {state['recency_days']}\n\n"
                    f"Raw results:\n{raw_results}"
                )
            ),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e
    evidence = list(dedup.values())

    # HARD RECENCY FILTER for open_book weekly roundup:
    # keep only items with a parseable ISO date and within the window.
    mode = state.get("mode", "closed_book")
    if mode == "open_book":
        as_of = date.fromisoformat(state["as_of"])
        cutoff = as_of - timedelta(days=int(state["recency_days"]))
        fresh: List[EvidenceItem] = []
        for e in evidence:
            d = _iso_to_date(e.published_at)
            if d and d >= cutoff:
                fresh.append(e)
        evidence = fresh

    return {"evidence": evidence}

# %%
# -----------------------------
# 5) Orchestrator (Plan)
# -----------------------------
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Flexibility:
- Do NOT use a fixed taxonomy unless it naturally fits.
- You may tag tasks (tags field), but tags are flexible.

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book (weekly news roundup):
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections (no scraping/RSS/how to fetch news) unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient fresh sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)
    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    # Force blog_kind for open_book
    forced_kind = "news_roundup" if mode == "open_book" else None

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n"
                    f"As-of: {state['as_of']} (recency_days={state['recency_days']})\n"
                    f"{'Force blog_kind=news_roundup' if forced_kind else ''}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}\n\n"
                    f"Instruction: If mode=open_book, your plan must NOT drift into a tutorial."
                )
            ),
        ]
    )

    # Ensure open_book forces the kind even if model forgets
    if forced_kind:
        plan.blog_kind = "news_roundup"

    return {"plan": plan}


# -----------------------------
# 6) Fanout
# -----------------------------
def fanout(state: State):
    assert state["plan"] is not None
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "as_of": state["as_of"],
                "recency_days": state["recency_days"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
# -----------------------------
# 7) Worker (write one section)
# -----------------------------
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard (prevents mid-blog topic drift):
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book (weekly news):
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true (hybrid sections):
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning (concepts, intuition) is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:
    
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")
    as_of = payload.get("as_of")
    recency_days = payload.get("recency_days")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    # Provide a compact evidence list for citation use
    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n"
                    f"As-of: {as_of} (recency_days={recency_days})\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    # deterministic ordering
    return {"sections": [(task.id, section_md)]}

# %%
# -----------------------------
# 8) Reducer (merge + save)
# -----------------------------
def reducer_node(state: State) -> dict:
    plan = state["plan"]
    if plan is None:
        raise ValueError("Reducer called without a plan.")

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    final_md = f"# {plan.blog_title}\n\n{body}\n"

    filename = f"{plan.blog_title}.md"
    Path(filename).write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
# -----------------------------
# 9) Build graph
# -----------------------------
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_node)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()

app

# %%
# -----------------------------
# 10) Runner
# -----------------------------
def run(topic: str, as_of: Optional[str] = None):
    if as_of is None:
        as_of = date.today().isoformat()

    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "as_of": as_of,
            "recency_days": 7,   # router may overwrite
            "sections": [],
            "final": "",
        }
    )

    plan: Plan = out["plan"]
    print("\n" + "=" * 100)
    print("TOPIC:", topic)
    print("AS_OF:", out.get("as_of"), "RECENCY_DAYS:", out.get("recency_days"))
    print("MODE:", out.get("mode"))
    print("BLOG_KIND:", plan.blog_kind)
    print("NEEDS_RESEARCH:", out.get("needs_research"))
    print("QUERIES:", (out.get("queries") or [])[:6])
    print("EVIDENCE_COUNT:", len(out.get("evidence", [])))
    if out.get("evidence"):
        print("EVIDENCE_SAMPLE:", [e.model_dump() for e in out["evidence"][:2]])
    print("TASKS:", len(plan.tasks))
    print("SAVED_MD_CHARS:", len(out.get("final", "")))
    print("=" * 100 + "\n")

    return out

# %%
run("Write a blog on Transformer Architecture")
# Out:
# Retrying langchain_mistralai.chat_models.ChatMistralAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised ConnectError: [WinError 10054] An existing connection was forcibly closed by the remote host.
# Retrying langchain_mistralai.chat_models.ChatMistralAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised ConnectError: [WinError 10054] An existing connection was forcibly closed by the remote host.
# Retrying langchain_mistralai.chat_models.ChatMistralAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised ConnectError: [WinError 10054] An existing connection was forcibly closed by the remote host.
# Retrying langchain_mistralai.chat_models.ChatMistralAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised ConnectError: [WinError 10054] An existing connection was forcibly closed by the remote host.
# Retrying langchain_mistralai.chat_models.ChatMistralAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised ConnectError: [WinError 10054] An existing connection was forcibly closed by the remote host.
# Retrying langchain_mistralai.chat_models.ChatMistralAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised ConnectError: [WinError 10054] An existing connection was forcibly closed by the remote host.
# Retrying langchain_mistralai.chat_models.ChatMistralAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised ConnectError: [WinError 10054] An existing connection was forcibly closed by the remote host.
# ====================================================================================================
# TOPIC: Write a blog on Transformer Architecture
# AS_OF: 2026-09-20 RECENCY_DAYS: 45
# MODE: hybrid
# BLOG_KIND: explainer
# NEEDS_RESEARCH: True
# QUERIES: ['latest advancements in transformer architecture', 'recent applications of transformer models', 'transformer architecture in natural language processing', 'transformer architecture in computer vision', 'transformer architecture in speech recognition', 'transformer architecture in reinforcement learning']
# EVIDENCE_COUNT: 0
# TASKS: 7
# SAVED_MD_CHARS: 18559
# ====================================================================================================
# {'topic': 'Write a blog on Transformer Architecture',
#  'mode': 'hybrid',
#  'needs_research': True,
#  'queries': ['latest advancements in transformer architecture',
#   'recent applications of transformer models',
#   'transformer architecture in natural language processing',
#   'transformer architecture in computer vision',
#   'transformer architecture in speech recognition',
#   'transformer architecture in reinforcement learning',
#   'transformer architecture in multimodal learning',
#   'transformer architecture in edge devices',
#   'transformer architecture in quantum computing',
#   'transformer architecture in bioinformatics'],
#  'evidence': [],
#  'plan': Plan(blog_title='Transformer Architecture', audience='Developers', tone='Technical', blog_kind='explainer', constraints=[], tasks=[Task(id=1, title='Introduction to Transformer Architecture', goal='Understand the basic components and purpose of the Transformer architecture.', bullets=['Explain the concept of self-attention and how it differs from traditional recurrent neural networks (RNNs).', 'Describe the encoder-decoder structure and its role in sequence-to-sequence tasks.', 'Highlight the advantages of Transformers over RNNs and CNNs in terms of parallel processing and long-range dependencies.'], target_words=300, tags=['self-attention', 'encoder-decoder', 'parallel processing'], requires_research=False, requires_citations=False, requires_code=False), Task(id=2, title='Self-Attention Mechanism', goal='Learn how the self-attention mechanism works and its significance in Transformers.', bullets=['Break down the steps involved in calculating attention scores: queries, keys, and values.', 'Explain how multi-head attention improves model performance by allowing the model to focus on different parts of the input simultaneously.', 'Discuss the computational complexity of self-attention and how it compares to traditional attention mechanisms.'], target_words=400, tags=['self-attention', 'multi-head attention', 'computational complexity'], requires_research=False, requires_citations=False, requires_code=True), Task(id=3, title='Positional Encoding', goal='Understand the role of positional encoding in Transformers and how it helps maintain the order of sequences.', bullets=['Explain why traditional Transformers lack inherent sequential information and the need for positional encoding.', 'Describe different types of positional encoding techniques, such as sinusoidal and learned positional embeddings.', 'Discuss the impact of positional encoding on model performance and its importance in various NLP tasks.'], target_words=350, tags=['positional encoding', 'sinusoidal embeddings', 'learned embeddings'], requires_research=False, requires_citations=False, requires_code=False), Task(id=4, title='Encoder and Decoder Components', goal='Explore the detailed components of the encoder and decoder in a Transformer model.', bullets=['Describe the layers within the encoder, including multi-head attention and feed-forward networks.', 'Explain the role of the decoder in generating output sequences and its interaction with the encoder.', 'Discuss the use of residual connections and layer normalization in both the encoder and decoder.'], target_words=450, tags=['encoder', 'decoder', 'residual connections'], requires_research=False, requires_citations=False, requires_code=False), Task(id=5, title='Training and Optimization', goal='Learn about the training process and optimization techniques used for Transformer models.', bullets=['Explain the use of teacher forcing during the training phase and its impact on model performance.', 'Describe the optimization techniques, such as Adam optimizer and learning rate scheduling.', 'Discuss the importance of regularization techniques like dropout and label smoothing in preventing overfitting.'], target_words=400, tags=['teacher forcing', 'Adam optimizer', 'dropout'], requires_research=False, requires_citations=False, requires_code=False), Task(id=6, title='Applications of Transformers', goal='Explore the various applications of Transformer models in different domains.', bullets=['Discuss the use of Transformers in natural language processing (NLP) tasks such as translation, summarization, and question answering.', 'Explain how Transformers are applied in computer vision tasks, such as image classification and object detection.', 'Highlight the emerging applications of Transformers in multimodal learning and reinforcement learning.'], target_words=450, tags=['NLP', 'computer vision', 'multimodal learning'], requires_research=True, requires_citations=True, requires_code=False), Task(id=7, title='Challenge ...
#  'as_of': '2026-09-20',
#  'recency_days': 45,
#  'sections': [(1,
#    '## Introduction to Transformer Architecture\n\nThe Transformer architecture, introduced in the paper "Attention Is All You Need" by Vaswani et al. in 2017, has revolutionized the field of natural language processing (NLP) and beyond. At its core, the Transformer relies on a mechanism called self-attention, which allows the model to weigh the importance of different words in a sentence when processing each word. This differs from traditional recurrent neural networks (RNNs), which process words sequentially, maintaining a hidden state that captures information from previous words. Self-attention, on the other hand, computes attention scores for all words in the sentence simultaneously, enabling the model to consider the entire context at once.\n\nThe Transformer architecture consists of an encoder-decoder structure, where the encoder processes the input sequence and the decoder generates the output sequence. The encoder is composed of multiple identical layers, each containing a self-attention mechanism and a feed-forward neural network. The decoder, similarly, has multiple layers but includes an additional attention mechanism that attends to the encoder\'s output. This structure is particularly well-suited for sequence-to-sequence tasks, such as machine translation, where the model needs to map an input sequence to an output sequence.\n\nOne of the key advantages of Transformers over RNNs and convolutional neural networks (CNNs) is their ability to process sequences in parallel. While RNNs and CNNs process words sequentially or in fixed-size windows, respectively, Transformers can process all words in a sentence simultaneously, thanks to the self-attention mechanism. This parallel processing capability significantly speeds up training and inference. Additionally, Transformers excel at capturing long-range dependencies, which is crucial for understanding the context of words in a sentence. Unlike RNNs, which may struggle to retain information over long sequences due to the vanishing gradient problem, Transformers can directly attend to any word in the input sequence, regardless of its distance. This makes Transformers particularly effective for tasks that require a deep understanding of the context, such as language translation and text generation.'),
#   (2,
#    "## Self-Attention Mechanism\n\nThe self-attention mechanism is a cornerstone of the Transformer architecture, enabling models to weigh the importance of different words in a sentence relative to each other. This mechanism is crucial for understanding context and relationships within the input data. Let's break down the steps involved in calculating attention scores, how multi-head attention improves model performance, and the computational complexity of self-attention.\n\n### Calculating Attention Scores\n\nThe self-attention mechanism involves three main components: queries (Q), keys (K), and values (V). These components are derived from the input embeddings. The attention scores are calculated using the dot product of the queries and keys, followed by a softmax function to obtain weights that sum to one. These weights are then used to compute a weighted sum of the values.\n\n```python\nimport torch\nimport torch.nn.functional as F\n\ndef self_attention(Q, K, V):\n    # Calculate attention scores\n    attention_scores = torch.matmul(Q, K.transpose(-2, -1)) / (K.size(-1) ** 0.5)\n    attention_weights = F.softmax(attention_scores, dim=-1)\n    # Compute weighted sum of values\n    output = torch.matmul(attention_weights, V)\n    return output\n```\n\n### Multi-Head Attention\n\nMulti-head attention improves model performance by allowing the model to focus on different parts of the input simultaneously. This is achieved by splitting the queries, keys, and values into multiple heads, each with its own attention mechanism. The outputs of these heads are concatenated and linearly transformed to produce the final output.\n\n```python\nclass MultiHeadAttention(nn.Module):\n    def __init__(self, d_model, num_heads):\n        super(MultiHeadAttention, self).__init__()\n        self.d_model = d_model\n        self.num_heads = num_heads\n        self.d_k = d_model // num_heads\n        self.W_Q = nn.Linear(d_model, d_model)\n        self.W_K = nn.Linear(d_model, d_model)\n        self.W_V = nn.Linear(d_model, d_model)\n        self.W_O = nn.Linear(d_model, d_model)\n\n    def forward(self, Q, K, V):\n        batch_size = Q.size(0)\n        Q = self.W_Q(Q).view(batch_size, -1, self.num_heads, self.d_k).transpose(1, 2)\n        K = self.W_K(K).view(batch_size, -1, self.num_heads, self.d_k).transpose(1, 2)\n        V = self.W_V(V).view(batch_size, -1, self.num_heads, self.d_k).transpose(1, 2)\n        attention_output = self_attention(Q, K, V)\n        attention_output = attention_output.transpose(1, 2).contiguous().view(batch_size, -1, self.d_model)\n        output = self.W_O(attention_output)\n        return output\n```\n\n### Computational Complexity\n\nThe computational complexity of self-attention is O(n^2 * d), where n is the sequence length and d is the dimensionality of the embeddings. This is higher than traditional attention mechanisms, which have a complexity of O(n * d). However, the parallelizable nature of self-attention makes it more efficient in practice, especially with modern hardware accelerations. Multi-head attention further increases the computational complexity to O(n^2 * d * h), where h is the number of heads, but this is offset by the improved model performance."),
#   (3,
#    '## Positional Encoding\n\nTransformers, a cornerstone of modern natural language processing (NLP), rely on self-attention mechanisms to process sequences. However, unlike recurrent neural networks (RNNs), Transformers do not inherently understand the order of elements in a sequence. This is because the self-attention mechanism treats each element in the sequence independently, without considering their positions. To address this limitation, positional encoding is introduced to inject information about the relative or absolute positions of tokens in the sequence.\n\n### Why Positional Encoding is Necessary\n\nTraditional Transformers lack sequential information because the input embeddings are processed in parallel. Without positional encoding, the model cannot distinguish between the order of words in a sentence. For example, the sentences "The cat sat on the mat" and "The mat sat on the cat" would be treated identically by the model, leading to incorrect interpretations.\n\n### Types of Positional Encoding\n\nThere are two primary types of positional encoding techniques:\n\n1. **Sinusoidal Positional Embeddings**: This method uses a function of sine and cosine to encode the position of each token. The embeddings are calculated as follows:\n\n   \\[\n   PE_{(pos, 2i)} = \\sin\\left(\\frac{pos}{10000^{2i/d_{\\text{model}}}}\\right)\n   \\]\n   \\[\n   PE_{(pos, 2i+1)} = \\cos\\left(\\frac{pos}{10000^{2i/d_{\\text{model}}}}\\right)\n   \\]\n\n   where \\(pos\\) is the position and \\(i\\) is the dimension. This approach allows the model to learn to attend by relative positions, making it more robust to longer sequences.\n\n2. **Learned Positional Embeddings**: In this method, the positional information is learned during training. Each position in the sequence is assigned a unique embedding vector, which is added to the token embeddings. This approach is simpler but requires more training data to converge.\n\n### Impact on Model Performance\n\nPositional encoding significantly impacts the performance of Transformers. By providing the model with information about the order of tokens, it enables the model to understand the context of each word in a sentence. This is crucial for tasks such as machine translation, text summarization, and question answering, where the order of words is essential.\n\nIn tasks like machine translation, positional encoding helps the model to align words in the source and target languages correctly. For example, in the sentence "I ate an apple," the model needs to know the position of each word to translate it accurately into another language. Without positional encoding, the model would struggle to maintain the correct word order, leading to translations that are grammatically incorrect or nonsensical.\n\nIn conclusion, positional encoding is a critical component of Transformers, enabling the model to understand the order of tokens in a sequence. By using techniques such as sinusoidal or learned positional embeddings, the model can achieve state-of-the-art performance in various NLP tasks.'),
#   (4,
#    "## Encoder and Decoder Components\n\nThe Transformer architecture consists of two main components: the encoder and the decoder. Each component is composed of multiple identical layers, each containing several sub-components that work together to process and generate sequences.\n\n### Encoder Layers\n\nThe encoder is responsible for processing the input sequence and generating a contextual representation. Each encoder layer consists of two main sub-components:\n\n- **Multi-Head Attention**: This mechanism allows the model to focus on different parts of the input sequence simultaneously. It consists of multiple attention heads, each computing attention scores independently. The multi-head attention mechanism helps the model capture various types of relationships in the input data.\n\n- **Feed-Forward Networks**: After the multi-head attention, the output is passed through a feed-forward network, which consists of two linear transformations with a ReLU activation in between. This network helps the model learn complex patterns in the data.\n\n### Decoder Layers\n\nThe decoder generates the output sequence step by step, using the encoder's output and its own previously generated tokens. Each decoder layer consists of three main sub-components:\n\n- **Masked Multi-Head Attention**: This mechanism is similar to the multi-head attention in the encoder, but it is masked to prevent the model from attending to future tokens. This ensures that the model generates each token based only on the previous tokens in the sequence.\n\n- **Encoder-Decoder Attention**: This mechanism allows the decoder to attend to the encoder's output. It helps the model focus on the relevant parts of the input sequence when generating each token in the output sequence.\n\n- **Feed-Forward Networks**: Similar to the encoder, the decoder also includes feed-forward networks to learn complex patterns in the data.\n\n### Residual Connections and Layer Normalization\n\nBoth the encoder and decoder layers use residual connections and layer normalization to improve the training of deep networks. Residual connections help mitigate the vanishing gradient problem by allowing gradients to flow directly through the network. Layer normalization normalizes the outputs of the sub-components, which helps stabilize the training process.\n\nBy combining these components, the Transformer architecture can effectively process and generate sequences, making it a powerful tool for various natural language processing tasks."),
#   (5,
#    "## Training and Optimization\n\nTraining Transformer models involves several key techniques to ensure effective learning and prevent overfitting. One such technique is **teacher forcing**, where the model is trained on the ground truth output at each time step during training, rather than its own predictions. This approach accelerates the learning process and helps the model converge faster. However, it can lead to a discrepancy between training and inference, where the model relies on its own predictions. To mitigate this, techniques like scheduled sampling can be employed, where the model gradually transitions from teacher forcing to using its own predictions.\n\nOptimization is crucial for training Transformer models efficiently. The **Adam optimizer** is widely used due to its adaptive learning rates for different parameters, which helps in handling sparse gradients and noisy data. It combines the benefits of AdaGrad and RMSProp, making it robust for training deep neural networks. Additionally, learning rate scheduling techniques, such as warm-up and decay, are employed to fine-tune the learning rate during training. This involves starting with a low learning rate and gradually increasing it to a peak value before decreasing it, which helps in stabilizing the training process.\n\nRegularization techniques play a vital role in preventing overfitting in Transformer models. **Dropout** is a common regularization method where random neurons are dropped during training, forcing the model to learn more robust features. This technique helps in reducing the co-adaptation of neurons and improves the model's generalization. Another effective regularization method is **label smoothing**, which involves replacing the hard labels with a distribution over all possible classes. This approach helps in reducing the model's overconfidence and improves its performance on unseen data. By incorporating these techniques, Transformer models can be trained effectively and generalized well to new data."),
#   (6,
#    "## Applications of Transformers\n\nTransformers have revolutionized various domains, demonstrating their versatility and effectiveness. This section explores their applications in natural language processing (NLP), computer vision, and emerging fields like multimodal learning and reinforcement learning.\n\n### Natural Language Processing (NLP)\n\nTransformers have significantly advanced NLP tasks, including translation, summarization, and question answering. For instance, models like BERT [^1] and T5 [^2] have set new benchmarks in understanding context and generating human-like text. These models leverage self-attention mechanisms to capture dependencies between words in a sentence, enabling them to perform well on tasks such as:\n\n- **Translation**: Models like Google's Transformer [^3] have improved machine translation by understanding the context of entire sentences rather than individual words.\n- **Summarization**: Abstractive summarization models use Transformers to generate concise summaries that capture the essence of longer documents.\n- **Question Answering**: Models like BERT have been fine-tuned to answer questions by understanding the context provided in a passage.\n\n### Computer Vision\n\nTransformers are not limited to NLP; they have also made significant strides in computer vision tasks. Vision Transformers (ViTs) [^4] have shown that Transformers can effectively process image data by dividing images into patches and applying self-attention mechanisms. These models have been successful in:\n\n- **Image Classification**: ViTs have achieved competitive performance on image classification tasks, often outperforming convolutional neural networks (CNNs) in some cases.\n- **Object Detection**: Models like DETR [^5] use Transformers to detect objects in images by predicting bounding boxes and class labels directly from the image patches.\n\n### Multimodal Learning\n\nMultimodal learning involves processing and integrating information from different modalities, such as text and images. Transformers are well-suited for this task due to their ability to handle sequential data and capture complex relationships. Applications include:\n\n- **Image Captioning**: Models like ViLBERT [^6] combine image and text data to generate descriptive captions for images.\n- **Visual Question Answering**: These models answer questions about images by understanding both the visual and textual information.\n\n### Reinforcement Learning\n\nTransformers are also being explored in reinforcement learning (RL) to handle sequential decision-making tasks. Models like Decision Transformer [^7] use Transformers to process sequences of states, actions, and rewards, enabling them to learn policies that generalize across different tasks.\n\nIn summary, Transformers have found widespread applications across various domains, demonstrating their adaptability and effectiveness. As research continues, we can expect even more innovative uses of these powerful models.\n\n[^1]: [BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding](https://arxiv.org/abs/1810.04805)\n[^2]: [Exploring the Limits of Transfer Learning with a Unified Text-to-Text Transformer](https://arxiv.org/abs/1910.10683)\n[^3]: [Attention Is All You Need](https://arxiv.org/abs/1706.03762)\n[^4]: [An Image is Worth 16x16 Words: Transformers for Image Recognition at Scale](https://arxiv.org/abs/2010.11929)\n[^5]: [End-to-End Object Detection with Transformers](https://arxiv.org/abs/2005.12872)\n[^6]: [ViLBERT: Pretraining Task-Agnostic Visiolinguistic Representations](https://arxiv.org/abs/1908.02265)\n[^7]: [Decision Transformer: Reinforcement Learning via Sequence Modeling](https://arxiv.org/abs/2106.01345)"),
#   (7,
#    '## Challenges and Future Directions\n\nTransformer models have revolutionized the field of natural language processing, but they come with significant challenges. One of the most pressing issues is the computational and memory requirements of large-scale Transformer models. These models, with their billions of parameters, demand substantial resources for training and inference. For instance, training a model like GPT-3 requires thousands of GPUs and significant energy consumption ([Source](https://arxiv.org/abs/2005.14165)). This high computational cost limits the accessibility of these models, particularly for researchers and developers in resource-constrained environments.\n\nAnother significant challenge is the interpretability and explainability of Transformer models. Despite their impressive performance, the inner workings of these models remain largely opaque. Understanding why a model makes a particular prediction is crucial for building trust and ensuring ethical use. Recent research has explored techniques such as attention visualization and saliency maps to shed light on the decision-making process of Transformers ([Source](https://arxiv.org/abs/1906.04710)). However, more work is needed to develop robust interpretability tools.\n\nLooking ahead, several future directions promise to address these challenges and expand the capabilities of Transformer models. One area of focus is the development of more efficient architectures. Techniques such as knowledge distillation, pruning, and quantization aim to reduce the size and computational requirements of these models without sacrificing performance ([Source](https://arxiv.org/abs/1910.01108)). Additionally, exploring new applications in domains like healthcare, finance, and scientific research could drive innovation and broaden the impact of Transformer technology.')],
#  'final': '# Transformer Architecture\n\n## Introduction to Transformer Architecture\n\nThe Transformer architecture, introduced in the paper "Attention Is All You Need" by Vaswani et al. in 2017, has revolutionized the field of natural language processing (NLP) and beyond. At its core, the Transformer relies on a mechanism called self-attention, which allows the model to weigh the importance of different words in a sentence when processing each word. This differs from traditional recurrent neural networks (RNNs), which process words sequentially, maintaining a hidden state that captures information from previous words. Self-attention, on the other hand, computes attention scores for all words in the sentence simultaneously, enabling the model to consider the entire context at once.\n\nThe Transformer architecture consists of an encoder-decoder structure, where the encoder processes the input sequence and the decoder generates the output sequence. The encoder is composed of multiple identical layers, each containing a self-attention mechanism and a feed-forward neural network. The decoder, similarly, has multiple layers but includes an additional attention mechanism that attends to the encoder\'s output. This structure is particularly well-suited for sequence-to-sequence tasks, such as machine translation, where the model needs to map an input sequence to an output sequence.\n\nOne of the key advantages of Transformers over RNNs and convolutional neural networks (CNNs) is their ability to process sequences in parallel. While RNNs and CNNs process words sequentially or in fixed-size windows, respectively, Transformers can process all words in a sentence simultaneously, thanks to the self-attention mechanism. This parallel processing capability significantly speeds up training and inference. Additionally, Transformers excel at capturing long-range dependencies, which is crucial for understanding the context of words in a sentence. Unlike RNNs, which may struggle to retain information over long sequences due to the vanishing gradient problem, Transformers can directly attend to any word in the input sequence, regardless of its distance. This makes Transformers particularly effective for tasks that require a deep understanding of the context, such as language translation and text generation.\n\n## Self-Attention Mechanism\n\nThe self-attention mechanism is a cornerstone of the Transformer architecture, enabling models to weigh the importance of different words in a sentence relative to each other. This mechanism is crucial for understanding context and relationships within the input data. Let\'s break down the steps involved in calculating attention scores, how multi-head attention improves model performance, and the computational complexity of self-attention.\n\n### Calculating Attention Scores\n\nThe self-attention mechanism involves three main components: queries (Q), keys (K), and values (V). These components are derived from the input embeddings. The attention scores are calculated using the dot product of the queries and keys, followed by a softmax function to obtain weights that sum to one. These weights are then used to compute a weighted sum of the values.\n\n```python\nimport torch\nimport torch.nn.functional as F\n\ndef self_attention(Q, K, V):\n    # Calculate attention scores\n    attention_scores = torch.matmul(Q, K.transpose(-2, -1)) / (K.size(-1) ** 0.5)\n    attention_weights = F.softmax(attention_scores, dim=-1)\n    # Compute weighted sum of values\n    output = torch.matmul(attention_weights, V)\n    return output\n```\n\n### Multi-Head Attention\n\nMulti-head attention improves model performance by allowing the model to focus on different parts of the input simultaneously. This is achieved by splitting the queries, keys, and values into multiple heads, each with its own attention mechanism. The outputs of these heads are concatenated and linearly transformed to produce the final output.\n\n```python\nclass Mul ...
